# %%
from A_a_json_writer import write_to_json
from A_Get_list_functional_start_pages import visit_functional_pages

base_url = "https://www.therichest.com/top-lists/top-250-richest-people-in-the-world/page/"
functional_pages = visit_functional_pages(base_url)
print(functional_pages)

# Save the list to a JSON file using the write_to_json function
write_to_json('sites_to_visit2.json', functional_pages)
# Out:
# An error occurred while accessing https://www.therichest.com/top-lists/top-250-richest-people-in-the-world/page/413/: 500 Server Error: Internal Server Error for url: https://www.therichest.com/top-lists/top-250-richest-people-in-the-world/page/413/
# ...

# %%
from B_load_json_file_fction import load_sites_to_visit
from C_Get_the_right_number_of_site import find_valid_sites

sites_to_visit = load_sites_to_visit('sites_to_visit2.json')


number_to_search = 250

extracted_number = find_valid_sites(sites_to_visit, number_to_search)

print(extracted_number)
# Out:
# 10

# %%
from D_Get_list_up_to_x_sites import get_urls_up_to_number

urls = get_urls_up_to_number(sites_to_visit, extracted_number)
print(urls)
# Out:
# ['https://www.therichest.com/top-lists/top-250-richest-people-in-the-world/page/1/', 'https://www.therichest.com/top-lists/top-250-richest-people-in-the-world/page/2/', 'https://www.therichest.com/top-lists/top-250-richest-people-in-the-world/page/3/', 'https://www.therichest.com/top-lists/top-250-richest-people-in-the-world/page/4/', 'https://www.therichest.com/top-lists/top-250-richest-people-in-the-world/page/5/', 'https://www.therichest.com/top-lists/top-250-richest-people-in-the-world/page/6/', 'https://www.therichest.com/top-lists/top-250-richest-people-in-the-world/page/7/', 'https://www.therichest.com/top-lists/top-250-richest-people-in-the-world/page/8/', 'https://www.therichest.com/top-lists/top-250-richest-people-in-the-world/page/9/', 'https://www.therichest.com/top-lists/top-250-richest-people-in-the-world/page/10/']

# %%
from E_Get_and_save_html_of_base_sites import persist_html_content

persist_html_content(urls, file_name='combined_data_just_trying2.html')
# Out:
# HTML content persisted to combined_data_just_trying2.html.

# %%
from F_load_html_function import load_html_document
from F_get_hrefs_function import extract_href_with_prefix

loaded_html = load_html_document(file_name='combined_data_just_trying2.html')
hrefs = extract_href_with_prefix(loaded_html, tag='a', prefix='/celebnetworth/', class_name='')
print(hrefs)
# Out:
# ['/celebnetworth/politician/president/vladimir-putin-net-worth/', '/celebnetworth/celebrity-business/tech-billionaire/jeff-bezos-net-worth/', '/celebnetworth/celebrity-business/ceo/elon-musk-net-worth/', '/celebnetworth/celebrity-business/retailers/the-mars-family-net-worth/', '/celebnetworth/celebrity-business/tech-billionaire/bill-gates-net-worth/', '/celebnetworth/celebrity-business/men/bernard-arnault-net-worth/', '/celebnetworth/celebrity-business/tech-billionaire/mark-zuckerberg-net-worth/', '/celebnetworth/celebrity-business/men/warren-buffett-net-worth/', '/celebnetworth/celebrity-business/tech-billionaire/sergey-brin-net-worth/', '/celebnetworth/celebrity-business/tech-billionaire/larry-page-net-worth/', '/celebnetworth/celebrity-business/tech-billionaire/larry-ellison-net-worth/', '/celebnetworth/celebrity-business/men/amancio-ortega-net-worth/', '/celebnetworth/celebrity-business/tech-billionaire/carlos-slim-net-worth/', '/celebnetworth/politician/michael-bloomberg-net-wor
# ...

# %%
from F_get_profile_links_function import join_prefix_and_links

prefix = 'https://www.therichest.com'
joined_links_ppl = join_prefix_and_links(hrefs, prefix)
write_to_json('ppl_links2.json', joined_links_ppl)

# %%
#persist the html of peoples' sites:

ppl_urls = load_sites_to_visit('ppl_links2.json')

persist_html_content(ppl_urls, 'ppl_soup2.html')
# Out:
# HTML content persisted to ppl_soup2.html.

# %%
from H_get_info import get_value
from H_get_info import get_person_info

#extracting the information about a person from an html:
ppl = load_html_document(file_name='ppl_soup2.html', parser='html.parser') #creating a BS object of html

get_value

get_person_info
# Out:
# <function H_get_info.get_person_info(ppl)>

# %%
from H_get_info import create_dictio_from_html


#creating a dictionary of person information retrieved above:
dictio = create_dictio_from_html(ppl)
print(dictio)

write_to_json('people_info2.json', dictio)
# Out:
# {'Vladimir Vladimirovich Putin': ['$200 Billion', 'Oil, Gas, Investments', '68', 'Leningrad, Soviet Union (St. Petersburg, Russia)', 'Divorced (Lyudmila Shkrebneva)', 'Russian', 'October 7, 1952', 'Russian', 'Politician, Businessman', 'Leningrad State University', '2 (Mariya, Yekaterina)'], 'Jeffrey Preston "Jeff" Bezos': ['$196 Billion', 'Internet retailing (Amazon)', '57', 'Albuquerque, New Mexico', 'Divorced (Mackenzie Bezos)', 'United States', 'January 12, 1964', 'American', 'Internet entrepreneur (Amazon)', 'Princeton University, River Oaks Elementary School, Miami Palmetto High School', 'Unknown'], 'Elon Musk': ['$163.9 Billion', 'SpaceX, Tesla Motors and PayPal', '49', 'Pretoria, South Africa', 'Divorced (Justine Wilson, Talulah Riley)', 'United States', 'June 28, 1971', 'Unknown', 'Entrepreneur', "Pretoria Boys High School, Queen's University, More", '7 (Nevada, Kai Musk, Xavier Musk, Griffin Musk, Damian Musk, Saxon Musk,  X AE A-XII)'], 'Unknown': ['$7.96 Billion', 'Busines
# ...
